# %% [markdown]
# # Web Scrapping
#
# ### Exercice:
#
# Scraping weather forecase from the The Weather Channel website `weather.com` using `requests` and `BeautifulSoup` libraries.
#
# 1. Implement a scraping script for getting 10 days weather forecasts of Benguerir city and Tanger City.
# 2. Store the data sets into Pandas DataFrame.
# 3. Use matplotlib library to plot the raining days of the two cities in the same figure.

# %% [markdown]
# ## Libraires importation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Tanger city

# %%
url1 = "https://weather.com/fr-MA/temps/10jours/l/701d5f2dd2a2b8cabcc505d69649a291257de6c1369a982396ea546ccb99198c"
html = urlopen(url1)

soup = BeautifulSoup(html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
container = soup.find('div', id="WxuDailyCard-main-a43097e1-49d7-4df7-9d1a-334b29628263")
days = container.find_all('h3')
get_days = []
for day in days:
    temp = day.find('span')
    if  temp != None:
        if temp.get_text() not in get_days:
            get_days.append(temp.get_text())
get_days
# Out:
# ['ven. 16',
#  'sam. 17',
#  'dim. 18',
#  'lun. 19',
#  'mar. 20',
#  'mer. 21',
#  'jeu. 22',
#  'ven. 23',
#  'sam. 24',
#  'dim. 25',
#  'lun. 26',
#  'mar. 27',
#  'mer. 28',
#  'jeu. 29',
#  'ven. 30']

# %%
container = soup.find('div', id="WxuDailyCard-main-a43097e1-49d7-4df7-9d1a-334b29628263")
container
summaries = container.find_all('summary')

# %%
def get_day_info(summary):
    data = []
    
    for divs in summary.find('div').find_all('div'):
        spans = divs.find_all('span')
        for span in spans:
            data.append(span.get_text())

        break
        
    return data

# %%
data = [get_day_info(summaries[day]) for day in range(15)]
data
# Out:
# [['18°', '/14°', '14°', 'Pluie', '78%', 'OSO 23 km/h'],
#  ['18°', '/12°', '12°', 'Légère pluie', '79%', 'SO 11 km/h'],
#  ['20°', '/15°', '15°', 'Plutôt ensoleillé', '14%', 'E 22 km/h'],
#  ['20°', '/14°', '14°', 'Peu nuageux', '12%', 'E 20 km/h'],
#  ['20°', '/15°', '15°', "Averses dans l'après-midi", '42%', 'ESE 16 km/h'],
#  ['19°', '/13°', '13°', 'Averses dans la matinée', '40%', 'SSO 11 km/h'],
#  ['19°', '/12°', '12°', 'Peu nuageux', '12%', 'ENE 10 km/h'],
#  ['19°', '/13°', '13°', 'Peu nuageux', '24%', 'SSE 10 km/h'],
#  ['19°', '/13°', '13°', 'Peu nuageux', '24%', 'S 11 km/h'],
#  ['18°', '/14°', '14°', 'Averses', '56%', 'SSE 16 km/h'],
#  ['18°', '/14°', '14°', 'Averses', '48%', 'SE 19 km/h'],
#  ['18°', '/14°', '14°', 'Averses', '55%', 'SSE 18 km/h'],
#  ['18°', '/14°', '14°', 'Averses', '39%', 'S 17 km/h'],
#  ['18°', '/14°', '14°', "Averses dans l'après-midi", '33%', 'S 18 km/h'],
#  ['19°', '/15°', '15°', 'Averses', '52%', 'S 16 km/h']]

# %%
columns = ['day', 'temperature_max', 'temperature_min', 'state', 
           'percentage_value', 'wind_speed']

# %%
df = pd.DataFrame(data=data)

# %%
df.drop(1, axis=1, inplace=True)

# %%
df = pd.concat([pd.DataFrame(data=get_days), df], axis=1)
df
# Out:
#           0    0    2                          3    4            5
# 0   ven. 16  18°  14°                      Pluie  78%  OSO 23 km/h
# 1   sam. 17  18°  12°               Légère pluie  79%   SO 11 km/h
# 2   dim. 18  20°  15°          Plutôt ensoleillé  14%    E 22 km/h
# 3   lun. 19  20°  14°                Peu nuageux  12%    E 20 km/h
# 4   mar. 20  20°  15°  Averses dans l'après-midi  42%  ESE 16 km/h
# 5   mer. 21  19°  13°    Averses dans la matinée  40%  SSO 11 km/h
# 6   jeu. 22  19°  12°                Peu nuageux  12%  ENE 10 km/h
# 7   ven. 23  19°  13°                Peu nuageux  24%  SSE 10 km/h
# 8   sam. 24  19°  13°                Peu nuageux  24%    S 11 km/h
# 9   dim. 25  18°  14°                    Averses  56%  SSE 16 km/h
# 10  lun. 26  18°  14°                    Averses  48%   SE 19 km/h
# 11  mar. 27  18°  14°                    Averses  55%  SSE 18 km/h
# 12  mer. 28  18°  14°                    Averses  39%    S 17 km/h
# 13  jeu. 29  18°  14°  Averses dans l'après-midi  33%    S 18 km/h
# 14  ven. 30  19°  15°                    Averses  52%    S 16 km/h

# %% [markdown]
# ## Pandas DataFrame for Tanger City

# %%
df.columns = columns
df
# Out:
#         day temperature_max temperature_min                      state  \
# 0   ven. 16             18°             14°                      Pluie
# 1   sam. 17             18°             12°               Légère pluie
# 2   dim. 18             20°             15°          Plutôt ensoleillé
# 3   lun. 19             20°             14°                Peu nuageux
# 4   mar. 20             20°             15°  Averses dans l'après-midi
# 5   mer. 21             19°             13°    Averses dans la matinée
# 6   jeu. 22             19°             12°                Peu nuageux
# 7   ven. 23             19°             13°                Peu nuageux
# 8   sam. 24             19°             13°                Peu nuageux
# 9   dim. 25             18°             14°                    Averses
# 10  lun. 26             18°             14°                    Averses
# 11  mar. 27             18°             14°                    Averses
# 12  mer. 28             18°             14°                    Averses
# 13  jeu. 29             18°             14°  Averses dans l'après-midi
# 14  ven. 30             19°             15°                    Averses
#
#    percentage_value   wind_speed
# 0               78%  OSO 23 km/h
# 1               79%   SO 11 km/h
# 2               14%    E 22 km/h
# 3               12%    E 20 km/h
# 4               42%  ESE 16 km/h
# 5               40%  SSO 11 km/h
# 6               12%  ENE 10 km/h
# 7               24%  SSE 10 km/h
# 8               24%    S 11 km/h
# 9               56%  SSE 16 km/h
# 10              48%   SE 19 km/h
# 11              55%  SSE 18 km/h
# 12              39%    S 17 km/h
# 13              33%    S 18 km/h
# 14              52%    S 16 km/h

# %% [markdown]
# ## Ben Guerir City

# %%
url1 = "https://weather.com/fr-MA/temps/10jours/l/f37580e42d804f6d54467e56dd9f296e15fe9a25db53ddee63601416ecc06111"
html = urlopen(url1)

soup = BeautifulSoup(html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
container = soup.find('div', id="WxuDailyCard-main-a43097e1-49d7-4df7-9d1a-334b29628263")
days = container.find_all('h3')
get_days = []
for day in days:
    temp = day.find('span')
    if  temp != None:
        if temp.get_text() not in get_days:
            get_days.append(temp.get_text())
get_days
# Out:
# ['ven. 16',
#  'sam. 17',
#  'dim. 18',
#  'lun. 19',
#  'mar. 20',
#  'mer. 21',
#  'jeu. 22',
#  'ven. 23',
#  'sam. 24',
#  'dim. 25',
#  'lun. 26',
#  'mar. 27',
#  'mer. 28',
#  'jeu. 29',
#  'ven. 30']

# %%
container = soup.find('div', id="WxuDailyCard-main-a43097e1-49d7-4df7-9d1a-334b29628263")
container
summaries = container.find_all('summary')

# %%
def get_day_info(summary):
    data = []
    
    for divs in summary.find('div').find_all('div'):
        spans = divs.find_all('span')
        for span in spans:
            data.append(span.get_text())

        break
        
    return data

# %%
data = [get_day_info(summaries[day]) for day in range(15)]
data
# Out:
# [['18°', '/10°', '10°', 'Peu nuageux', '21%', 'OSO 18 km/h'],
#  ['19°', '/8°', '8°', 'Peu nuageux', '15%', 'E 12 km/h'],
#  ['22°', '/8°', '8°', 'Peu nuageux', '14%', 'E 11 km/h'],
#  ['23°', '/8°', '8°', 'Plutôt ensoleillé', '7%', 'E 12 km/h'],
#  ['23°', '/9°', '9°', 'Peu nuageux', '7%', 'S 14 km/h'],
#  ['21°', '/7°', '7°', 'Ensoleillé', '7%', 'ENE 13 km/h'],
#  ['20°', '/6°', '6°', 'Ensoleillé', '8%', 'ENE 12 km/h'],
#  ['21°', '/7°', '7°', 'Ensoleillé', '7%', 'S 12 km/h'],
#  ['21°', '/8°', '8°', 'Peu nuageux', '7%', 'SSO 14 km/h'],
#  ['20°', '/8°', '8°', "Averses dans l'après-midi", '34%', 'SSO 21 km/h'],
#  ['19°', '/8°', '8°', 'Peu nuageux', '21%', 'SSO 15 km/h'],
#  ['20°', '/8°', '8°', 'Peu nuageux', '7%', 'S 15 km/h'],
#  ['20°', '/9°', '9°', 'Peu nuageux', '10%', 'SSO 16 km/h'],
#  ['20°', '/9°', '9°', 'Peu nuageux', '7%', 'S 14 km/h'],
#  ['21°', '/9°', '9°', 'Peu nuageux', '11%', 'S 15 km/h']]

# %%
columns = ['day', 'temperature_max', 'temperature_min', 'state', 
           'percentage_value', 'wind_speed']

# %%
df = pd.DataFrame(data=data)

# %%
df.drop(1, axis=1, inplace=True)

# %%
df = pd.concat([pd.DataFrame(data=get_days), df], axis=1)
df
# Out:
#           0    0    2                          3    4            5
# 0   ven. 16  18°  10°                Peu nuageux  21%  OSO 18 km/h
# 1   sam. 17  19°   8°                Peu nuageux  15%    E 12 km/h
# 2   dim. 18  22°   8°                Peu nuageux  14%    E 11 km/h
# 3   lun. 19  23°   8°          Plutôt ensoleillé   7%    E 12 km/h
# 4   mar. 20  23°   9°                Peu nuageux   7%    S 14 km/h
# 5   mer. 21  21°   7°                 Ensoleillé   7%  ENE 13 km/h
# 6   jeu. 22  20°   6°                 Ensoleillé   8%  ENE 12 km/h
# 7   ven. 23  21°   7°                 Ensoleillé   7%    S 12 km/h
# 8   sam. 24  21°   8°                Peu nuageux   7%  SSO 14 km/h
# 9   dim. 25  20°   8°  Averses dans l'après-midi  34%  SSO 21 km/h
# 10  lun. 26  19°   8°                Peu nuageux  21%  SSO 15 km/h
# 11  mar. 27  20°   8°                Peu nuageux   7%    S 15 km/h
# 12  mer. 28  20°   9°                Peu nuageux  10%  SSO 16 km/h
# 13  jeu. 29  20°   9°                Peu nuageux   7%    S 14 km/h
# 14  ven. 30  21°   9°                Peu nuageux  11%    S 15 km/h

# %% [markdown]
# ## Pandas DataFrame for Ben Guerir City

# %%
df.columns = columns
df
# Out:
#         day temperature_max temperature_min                      state  \
# 0   ven. 16             18°             10°                Peu nuageux
# 1   sam. 17             19°              8°                Peu nuageux
# 2   dim. 18             22°              8°                Peu nuageux
# 3   lun. 19             23°              8°          Plutôt ensoleillé
# 4   mar. 20             23°              9°                Peu nuageux
# 5   mer. 21             21°              7°                 Ensoleillé
# 6   jeu. 22             20°              6°                 Ensoleillé
# 7   ven. 23             21°              7°                 Ensoleillé
# 8   sam. 24             21°              8°                Peu nuageux
# 9   dim. 25             20°              8°  Averses dans l'après-midi
# 10  lun. 26             19°              8°                Peu nuageux
# 11  mar. 27             20°              8°                Peu nuageux
# 12  mer. 28             20°              9°                Peu nuageux
# 13  jeu. 29             20°              9°                Peu nuageux
# 14  ven. 30             21°              9°                Peu nuageux
#
#    percentage_value   wind_speed
# 0               21%  OSO 18 km/h
# 1               15%    E 12 km/h
# 2               14%    E 11 km/h
# 3                7%    E 12 km/h
# 4                7%    S 14 km/h
# 5                7%  ENE 13 km/h
# 6                8%  ENE 12 km/h
# 7                7%    S 12 km/h
# 8                7%  SSO 14 km/h
# 9               34%  SSO 21 km/h
# 10              21%  SSO 15 km/h
# 11               7%    S 15 km/h
# 12              10%  SSO 16 km/h
# 13               7%    S 14 km/h
# 14              11%    S 15 km/h
